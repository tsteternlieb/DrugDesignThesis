# %%
import sys
import copy
import random
sys.path.append('..')


from inference_utils import Handler, GraphFromMolTree
from pretrain_eval import checkIdx
from rdkit import Chem
from rdkit.Chem import Draw
import torch
import dgl


import matplotlib.pyplot as plt
import networkx as nx


DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
from enviroment.Keku import AdjustAromaticNs
from enviroment.utils import permuteAtomToEnd, mol_to_graph_full, MolFromGraphsFULL, SanitizeNoKEKU
from inference_utils import Handler, testModelReward
from pretrain_eval import Profiler
from Architectures.models import Actor, dropout_inference
# handler = Handler('../TrainingMain/QED_WEIGHT13_400000',fine_tuned=True)
# profiler = Profiler('../MODELS/SmallModelEntropy13/supervised_model')
#handler = Handler(('../TrainingMain/DOCK_RESET/ckpt_4/actor_checkpoint','../TrainingMain/DOCK_RESET/config.yaml'))
# handler = Handler(('../TrainingMain/QED+SYNTH_rawtrain/fine_tuned_model','../TrainingMain/QED+SYNTH_rawtrain/config.yaml'))
handler = Handler(('../TrainingMain/QED+SYNTH/ckpt_0/actor_checkpoint','../TrainingMain/QED+SYNTH/config.yaml'))
# TrainingMain/QED+SYNTH+LOGP
# handler = Handler('../TrainingMain/QED_WEIGHT13_400000')
# Out:
# ('../TrainingMain/QED+SYNTH/ckpt_0/actor_checkpoint', '../TrainingMain/QED+SYNTH/config.yaml') <class 'tuple'>

# %%
# mol = Chem.RWMol(Chem.MolFromSmiles("N.NC(=O)Cc1nnc(N)s1"))
# tree = handler.treeSearch(mol, 5,8,True)
# tree.DisplayTree()

# %%
l = handler.produceMols(6)
# Out:
# generated 0 molecules

# %%
Draw.MolsToGridImage(l,molsPerRow=3,subImgSize=(200,200))

# %%
testModelReward(handler,'../GraphDecomp/SmallDrug.csv',['DOCK'],30)
# Out:
# /home/theo/anaconda3/envs/prawn/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1424775/4038897372.py in <module>
# ----> 1 testModelReward(handler,'../GraphDecomp/SmallDrugs.csv',['DOCK'],30)
#
# ~/Desktop/GoodThesis/DrugDesignThesis/CLEAN/Inference/inference_utils.py in testModelReward(handler, path, reward, num)
#     369     """
#     370
# --> 371     drugs = pd.read_csv(path,error_bad_lines=False,delimiter=';')
#     372     smiles_values = drugs['Smiles'].values
#     373     samples_true = random.sample(list(smiles_values),num)
#
# ~/anaconda3/envs/prawn/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
type(Chem.MolFromSmiles("C"))
# Out:
# rdkit.Chem.rdchem.Mol

# %%
Chem.MolFromSmiles('C1=CC=NC=C1')
